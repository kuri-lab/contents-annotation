# %%
import cv2
import glob
import numpy as np
from PIL import Image
from natsort import natsorted
from matplotlib import pyplot as plt

# %%
import random

# %%
import os
from tqdm import tqdm

# %%
list_target = glob.glob('templates/Image/targets/*')

# %%
random.choice(list_target)
# Out:
# 'templates/Image/targets/ヨーゼフ_00034.png'

# %%
targets
# Out:
# ['templates/Image/targets/sketch_312_000291.png',
#  'templates/Image/targets/天下すえ_00013.png',
#  'templates/Image/targets/カウフマン母_由季江_00017.png',
#  'templates/Image/targets/ベリコフ_00002.png',
#  'templates/Image/targets/ヘンリー・オネガー_00009.png',
#  'templates/Image/targets/ヨーゼフ_00018.png',
#  'templates/Image/targets/sketch_168_000116.png',
#  'templates/Image/targets/sketch_276_000121.png',
#  'templates/Image/targets/美倉洋介_00062.png',
#  'templates/Image/targets/sketch_266_000127.png',
#  'templates/Image/targets/sketch_277_000496.png',
#  'templates/Image/targets/ミルダ素顔_00011.png',
#  'templates/Image/targets/北村市郎_00022.png',
#  'templates/Image/targets/モブ男00011.png',
#  'templates/Image/targets/sketch_067_000012.png',
#  'templates/Image/targets/sketch_002_000095.png',
#  'templates/Image/targets/i077ra-fn.png',
#  'templates/Image/targets/sketch_003_000187.png',
#  'templates/Image/targets/東園寺_00002.png',
#  'templates/Image/targets/モブ男5学者_00002.png',
# ...
