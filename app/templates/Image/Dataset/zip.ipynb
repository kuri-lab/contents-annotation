# %%
# !zip -r sample_target.zip sample_target/
# Out:
#   adding: sample_target/ (stored 0%)
#   adding: sample_target/sketch_264_000305.jpg (deflated 0%)
#   adding: sample_target/02662.jpg (deflated 36%)
#   adding: sample_target/sketch_311_000080.jpg (deflated 11%)
#   adding: sample_target/sketch_206_000010.jpg (deflated 7%)
#   adding: sample_target/05979.jpg (deflated 22%)
#   adding: sample_target/05939.jpg (deflated 31%)
#   adding: sample_target/sketch_267_000502.jpg (deflated 4%)
#   adding: sample_target/sketch_244_000045.jpg (deflated 6%)
#   adding: sample_target/00897.jpg (deflated 33%)
#   adding: sample_target/03700.jpg (deflated 36%)
#   adding: sample_target/sketch_303_000165.jpg (deflated 9%)
#   adding: sample_target/sketch_257_000125.jpg (deflated 16%)
#   adding: sample_target/02917.jpg (deflated 36%)
#   adding: sample_target/05740.jpg (deflated 26%)
#   adding: sample_target/03486.jpg (deflated 39%)
#   adding: sample_target/sketch_165_000210.jpg (deflated 19%)
#   adding: sample_target/01898.jpg (deflated 38%)
# ...

# %%
# !unzip dataset_tezuka_folder.zip
# Out:
# Archive:  dataset_tezuka_folder.zip
#    creating: dataset_tezuka_folder/
#   inflating: __MACOSX/._dataset_tezuka_folder
#    creating: dataset_tezuka_folder/ステレオタイプ　IL２巻に掲載/
#   inflating: __MACOSX/dataset_tezuka_folder/._ステレオタイプ　IL２巻に掲載
#    creating: dataset_tezuka_folder/アポロの歌１−3/
#   inflating: __MACOSX/dataset_tezuka_folder/._アポロの歌１−3
#    creating: dataset_tezuka_folder/人間昆虫記1/
#   inflating: __MACOSX/dataset_tezuka_folder/._人間昆虫記1
#    creating: dataset_tezuka_folder/やけっぱちのマリア/
#   inflating: __MACOSX/dataset_tezuka_folder/._やけっぱちのマリア
#    creating: dataset_tezuka_folder/MT262_I(アイエル）L1巻/
#   inflating: __MACOSX/dataset_tezuka_folder/._MT262_I(アイエル）L1巻
#    creating: dataset_tezuka_folder/MT372_アドルフに告ぐ1巻/
#   inflating: __MACOSX/dataset_tezuka_folder/._MT372_アドルフに告ぐ1巻
#    creating: dataset_tezuka_folder/虹のプレリュードMT87/
#   inflating: __MACOSX/dataset_tezuka_folder/._虹のプレリュードMT87
#    creating: dataset_tezuka_folder/地球を呑む/
# ...

# %%
# !rm -rf __MACOSX/

# %%
# !unzip dataset_muct_crop.zip
# Out:
# Archive:  dataset_muct_crop.zip
#    creating: dataset_muct_crop/
#   inflating: dataset_muct_crop/crop_i233vd-fn.jpg
#   inflating: dataset_muct_crop/crop_i241ua-mn.jpg
#   inflating: dataset_muct_crop/crop_i614yc-fn.jpg
#   inflating: dataset_muct_crop/crop_i601zd-fn.jpg
#   inflating: dataset_muct_crop/crop_i059rd-mg.jpg
#   inflating: dataset_muct_crop/crop_i226ud-fg.jpg
#   inflating: dataset_muct_crop/crop_i240ua-mn.jpg
#   inflating: dataset_muct_crop/crop_i615yc-fn.jpg
#   inflating: dataset_muct_crop/crop_i600zd-fn.jpg
#   inflating: dataset_muct_crop/crop_i058rc-mn.jpg
#   inflating: dataset_muct_crop/crop_i053sb-fg.jpg
#   inflating: dataset_muct_crop/crop_i030sc-fg.jpg
#   inflating: dataset_muct_crop/crop_i415wd-fn.jpg
#   inflating: dataset_muct_crop/crop_i031sd-fn.jpg
#   inflating: dataset_muct_crop/crop_i245ub-fn.jpg
#   inflating: dataset_muct_crop/crop_i014sb-fn.jpg
#   inflating: dataset_muct_crop/crop_i289ta-mg.jpg
# ...

# %%
ls dataset_muct_crop/
# Out:
# crop_i000qa-fn.jpg  crop_i062re-fn.jpg  crop_i234td-mg.jpg  crop_i296vc-mg.jpg
# crop_i000qb-fn.jpg  crop_i062sa-fn.jpg  crop_i234te-mg.jpg  crop_i296vd-mg.jpg
# crop_i000qc-fn.jpg  crop_i062sb-fn.jpg  crop_i234ua-mg.jpg  crop_i296ve-mg.jpg
# crop_i000qd-fn.jpg  crop_i062sc-fn.jpg  crop_i234ub-mg.jpg  crop_i297ta-mn.jpg
# crop_i000qe-fn.jpg  crop_i062sd-fn.jpg  crop_i234uc-mg.jpg  crop_i297tb-mn.jpg
# crop_i000ra-fn.jpg  crop_i062se-fn.jpg  crop_i234ud-mg.jpg  crop_i297tc-mn.jpg
# crop_i000rb-fn.jpg  crop_i063qa-fn.jpg  crop_i234ue-mg.jpg  crop_i297td-mn.jpg
# crop_i000rc-fn.jpg  crop_i063qb-fn.jpg  crop_i234va-mg.jpg  crop_i297te-mn.jpg
# crop_i000rd-fn.jpg  crop_i063qc-fn.jpg  crop_i234vb-mg.jpg  crop_i297ua-mn.jpg
# crop_i000re-fn.jpg  crop_i063qd-fn.jpg  crop_i234vc-mg.jpg  crop_i297ub-mn.jpg
# crop_i000sa-fn.jpg  crop_i063qe-fn.jpg  crop_i234vd-mg.jpg  crop_i297uc-mn.jpg
# crop_i000sb-fn.jpg  crop_i063ra-fn.jpg  crop_i234ve-mg.jpg  crop_i297ud-mn.jpg
# ...
